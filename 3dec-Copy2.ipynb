# %%
import numpy as np
from matplotlib import pyplot as plt
import pickle as pkl

# %%
with open('market2.pkl','rb') as f:
            print
            alldata = pkl.load(f)

# %%
len(alldata)
# Out:
# 14

# %%
alldata[0][2].shape
# Out:
# (256, 256, 128, 3)

# %%
#a = np.concatenate((alldata[1][1],alldata[1][2]),axis =2)
a=alldata[1][1]
a = np.clip(a,0,255.0).astype(np.uint8)

# %%
plt.imshow(a[193])
plt.axis('off')
# Out:
# (-0.5, 127.5, 255.5, -0.5)

# %%
plt.imshow(a[140])

# %%
plt.imshow(a[142])
plt.axis('off')
# Out:
# (-0.5, 255.5, 255.5, -0.5)

# %%
plt.imshow(a[143])

# %%
plt.imshow(a[144])

# %%
plt.imshow(a[145])

# %%
plt.imshow(a[150])
