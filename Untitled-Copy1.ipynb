# %%
import numpy as np
from matplotlib import pyplot as plt
import pickle as pkl

# %%
with open('market2.pkl','rb') as f:
            alldata = pkl.load(f)

# %%
len(alldata)
# Out:
# 14

# %%
alldata[0][1].shape
# Out:
# (256, 256, 128, 3)

# %%
a = np.concatenate((alldata[0][1],alldata[0][2]),axis =2)
a=alldata[0][1]
a = np.clip(a,0,255.0).astype(np.uint8)

# %%
plt.imshow(a[0])

# %%
plt.imshow(a[140])
plt.axis('off')
# Out:
# (-0.5, 127.5, 255.5, -0.5)

# %%
plt.imshow(a[255])

# %%
plt.imshow(a[55])
