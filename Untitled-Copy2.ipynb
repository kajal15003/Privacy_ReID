# %%
import numpy as np
from matplotlib import pyplot as plt
import pickle as pkl

# %%
with open('3216lowres.pkl','rb') as f:
            alldata = pkl.load(f)

# %%
len(alldata)
# Out:
# 14

# %%
alldata[0][1].shape
# Out:
# (256, 256, 128, 3)

# %%
#a = np.concatenate((alldata[0][1],alldata[0][2]),axis =2)
a=alldata[0][2]
a = np.clip(a,0,255.0).astype(np.uint8)

# %%
plt.imshow(a[5])

# %%
plt.imshow(a[14])

# %%
plt.imshow(a[15])

# %%
plt.imshow(a[16])

# %%
plt.imshow(a[17])

# %%
plt.imshow(a[18])
