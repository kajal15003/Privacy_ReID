# %%
import numpy as np
from matplotlib import pyplot as plt
import pickle as pkl

# %%
with open('embImgRe_dec.pkl','rb') as f:
            alldata = pkl.load(f)

# %%
len(alldata)
# Out:
# 14

# %%
alldata[0][1].shape
# Out:
# (256, 256, 128, 3)

# %%
a = np.concatenate((alldata[0][1],alldata[0][2]),axis =2)
a = np.clip(a,0,255.0).astype(np.uint8)

# %%
plt.imshow(a[34])

# %%
plt.imshow(a[26])

# %%
plt.imshow(a[255])

# %%
plt.imshow(a[55])

# %%
import tensorflow as tf
a=tf.eye(2)

# %%
for i in a:
    for j in a:
          if (i==j):
            a[1]=2
            print(a)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-ae733b947c54> in <module>
#       1 for i in a:
#       2     for j in a:
# ----> 3           if (i==j):
#       4             a[1]=2
#       5             print(a)
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/framework/ops.py in __bool__(self)
#    1068
#    1069   def __bool__(self):
# -> 1070     return bool(self._numpy())
#    1071
#    1072   __nonzero__ = __bool__
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
