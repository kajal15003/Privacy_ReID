# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np

# %%
x= [69.22,69.79,58.28,61.53,68.34,55.9,57.65,56.4]
y = [72.74, 74.44, 47.68, 53.15, 50.27, 37.26, 33.55,22.3]
labels = ["Baseline", "Clean-Decoder", "De-ID_blur", "De-ID_obfus", "De-ID_pixel", "Adv-ID", "Ours"]
c1 = (1,0, 0)
c2 = (0, 1, 0)
c3 = (0, 0, 1)
c4 = (1, 0,1)
c5= (1,1,0)

colors = [c1,c2,c2,c2,c2,c3,c4,c5]

sizes = 3000* rng.rand(8)
plt.xticks(np.arange(min(x)-5.9, max(x)+1, 1))

plt.yticks(np.arange(min(y)-2, max(y), 5))

plt.scatter(x, y, c=colors, s=sizes, alpha=0.3,cmap='viridis', label=labels)
#plt.colorbar();  # show color scale
